# %% [markdown]
# # Environment & Config Check
#
# This notebook verifies that the `fe-course` environment, `.env` configuration, and NumPy are working correctly for Homework 02.

# %%
import sys
sys.path.append("..")

from src.config import load_env, get_key
import numpy as np

# Load environment variables from .env
load_env()

# Check API_KEY is present
api_key_present = get_key("API_KEY") is not None
print("API_KEY present:", api_key_present)

# NumPy mini-demo
arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Vectorized * 10:", arr * 10)
# Out:
# API_KEY present: True
# Array: [1 2 3 4 5]
# Mean: 3.0
# Vectorized * 10: [10 20 30 40 50]
